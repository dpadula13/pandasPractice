# %%
import numpy as np 
import pandas as pd

# %%
s = pd.Series([1,3,5, np.nan, 6, 8])

s
# Out:
# 0    1.0
# 1    3.0
# 2    5.0
# 3    NaN
# 4    6.0
# 5    8.0
# dtype: float64

# %%
dates = pd.date_range("20130101", periods=6)

dates 

df = pd.DataFrame(np.random.randn(6,4), index=dates, columns=list("ABCD"))
df
# Out:
#                    A         B         C         D
# 2013-01-01  0.694149  0.277558 -1.622971  1.016996
# 2013-01-02 -0.729708 -1.136329  0.509865  1.844282
# 2013-01-03  1.105291  0.828767  0.098230 -1.716570
# 2013-01-04  1.741801 -0.931883  1.492771  0.397975
# 2013-01-05  0.176095 -2.725450  2.009585  0.474134
# 2013-01-06  0.448951  0.063204  0.242521 -0.273548

# %%
(np.random.randn(6,4))
# Out:
# array([[ 1.11995744,  0.44631051, -0.60380094, -0.70752679],
#        [ 1.64177404, -0.67618062,  1.82074456, -0.95553649],
#        [ 1.07393077,  1.20907397, -0.20871522,  0.94188164],
#        [ 0.70861327, -0.25531736, -0.7458854 , -0.88446046],
#        [ 0.22475131,  0.54299904,  1.61329575,  0.93350531],
#        [-0.69114754,  1.48617695, -1.15542767, -1.34036191]])

# %%
df2 = pd.DataFrame({
    "A": 1.0,
    "B": pd.Timestamp("20130102"),
    "C": pd.Series(1, index=list(range(5)), dtype="float32"), 
    "D": np.array([6] * 5, dtype="int32"),
    "E": pd.Categorical(["test", "test", "test", "train", "train"]),
    "F": "foo"
})

df2
# Out:
#      A          B    C  D      E    F
# 0  1.0 2013-01-02  1.0  6   test  foo
# 1  1.0 2013-01-02  1.0  6   test  foo
# 2  1.0 2013-01-02  1.0  6   test  foo
# 3  1.0 2013-01-02  1.0  6  train  foo
# 4  1.0 2013-01-02  1.0  6  train  foo

# %%
df2.dtypes
# Out:
# A          float64
# B    datetime64[s]
# C          float32
# D            int32
# E         category
# F           object
# dtype: object

# %%
df.head()

df.tail(2)
# Out:
#                    A         B         C         D
# 2013-01-05  0.176095 -2.725450  2.009585  0.474134
# 2013-01-06  0.448951  0.063204  0.242521 -0.273548

# %%
df.index
df.columns
df
# Out:
#                    A         B         C         D
# 2013-01-01  0.694149  0.277558 -1.622971  1.016996
# 2013-01-02 -0.729708 -1.136329  0.509865  1.844282
# 2013-01-03  1.105291  0.828767  0.098230 -1.716570
# 2013-01-04  1.741801 -0.931883  1.492771  0.397975
# 2013-01-05  0.176095 -2.725450  2.009585  0.474134
# 2013-01-06  0.448951  0.063204  0.242521 -0.273548

# %%
df[df.index == '2013-01-02']
# Out:
#                    A         B         C         D
# 2013-01-02 -0.729708 -1.136329  0.509865  1.844282

# %%
df.to_numpy()
# Out:
# array([[ 0.6941491 ,  0.27755767, -1.62297075,  1.0169957 ],
#        [-0.72970831, -1.13632858,  0.50986529,  1.84428202],
#        [ 1.10529127,  0.82876734,  0.09822986, -1.7165698 ],
#        [ 1.74180087, -0.93188322,  1.4927708 ,  0.39797487],
#        [ 0.17609516, -2.72544992,  2.00958494,  0.4741337 ],
#        [ 0.44895085,  0.0632044 ,  0.24252124, -0.27354751]])

# %%
df2.dtypes 

df2.to_numpy()
# Out:
# array([[1.0, Timestamp('2013-01-02 00:00:00'), 1.0, 6, 'test', 'foo'],
#        [1.0, Timestamp('2013-01-02 00:00:00'), 1.0, 6, 'test', 'foo'],
#        [1.0, Timestamp('2013-01-02 00:00:00'), 1.0, 6, 'test', 'foo'],
#        [1.0, Timestamp('2013-01-02 00:00:00'), 1.0, 6, 'train', 'foo'],
#        [1.0, Timestamp('2013-01-02 00:00:00'), 1.0, 6, 'train', 'foo']],
#       dtype=object)

# %%
df.describe()
# Out:
#               A         B         C         D
# count  6.000000  6.000000  6.000000  6.000000
# mean   0.572763 -0.604022  0.455000  0.290545
# std    0.840723  1.278011  1.263891  1.211097
# min   -0.729708 -2.725450 -1.622971 -1.716570
# 25%    0.244309 -1.085217  0.134303 -0.105667
# 50%    0.571550 -0.434339  0.376193  0.436054
# 75%    1.002506  0.223969  1.247044  0.881280
# max    1.741801  0.828767  2.009585  1.844282

# %%
df.T
# Out:
#    2013-01-01  2013-01-02  2013-01-03  2013-01-04  2013-01-05  2013-01-06
# A    0.694149   -0.729708    1.105291    1.741801    0.176095    0.448951
# B    0.277558   -1.136329    0.828767   -0.931883   -2.725450    0.063204
# C   -1.622971    0.509865    0.098230    1.492771    2.009585    0.242521
# D    1.016996    1.844282   -1.716570    0.397975    0.474134   -0.273548

# %%
df.sort_index(axis=0, ascending=True)
# Out:
#                    A         B         C         D
# 2013-01-01  0.694149  0.277558 -1.622971  1.016996
# 2013-01-02 -0.729708 -1.136329  0.509865  1.844282
# 2013-01-03  1.105291  0.828767  0.098230 -1.716570
# 2013-01-04  1.741801 -0.931883  1.492771  0.397975
# 2013-01-05  0.176095 -2.725450  2.009585  0.474134
# 2013-01-06  0.448951  0.063204  0.242521 -0.273548

# %%
df.sort_values(by="B", ascending=True)
df
# Out:
#                    A         B         C         D
# 2013-01-01  0.694149  0.277558 -1.622971  1.016996
# 2013-01-02 -0.729708 -1.136329  0.509865  1.844282
# 2013-01-03  1.105291  0.828767  0.098230 -1.716570
# 2013-01-04  1.741801 -0.931883  1.492771  0.397975
# 2013-01-05  0.176095 -2.725450  2.009585  0.474134
# 2013-01-06  0.448951  0.063204  0.242521 -0.273548

# %%
df.A
# Out:
# 2013-01-01    0.694149
# 2013-01-02   -0.729708
# 2013-01-03    1.105291
# 2013-01-04    1.741801
# 2013-01-05    0.176095
# 2013-01-06    0.448951
# Freq: D, Name: A, dtype: float64

# %%
df[0:5]
# Out:
#                    A         B         C         D
# 2013-01-01  0.694149  0.277558 -1.622971  1.016996
# 2013-01-02 -0.729708 -1.136329  0.509865  1.844282
# 2013-01-03  1.105291  0.828767  0.098230 -1.716570
# 2013-01-04  1.741801 -0.931883  1.492771  0.397975
# 2013-01-05  0.176095 -2.725450  2.009585  0.474134

# %%
df.loc[dates[1]]
# Out:
# A   -0.729708
# B   -1.136329
# C    0.509865
# D    1.844282
# Name: 2013-01-02 00:00:00, dtype: float64

# %%
df.loc[:, ["A", "B"]]

# %% [markdown]
# Why is first using index or rows to find the date and the second is working with columns. Pandas is using row based so label based and it works with row first column second

# %%
df.loc[[dates[0], dates[1]], "A": "C"]
# Out:
#                    A         B         C
# 2013-01-01  0.694149  0.277558 -1.622971
# 2013-01-02 -0.729708 -1.136329  0.509865

# %%
df.loc["20130102": "20130104", "A":"C"]
# Out:
#                    A         B         C
# 2013-01-02 -0.729708 -1.136329  0.509865
# 2013-01-03  1.105291  0.828767  0.098230
# 2013-01-04  1.741801 -0.931883  1.492771

# %% [markdown]
# Use square brackets if we want to select a listing of 1,2,3,4 of items. No square brackets if we want to slice the data

# %%
df.at[dates[0], "A"]
# Out:
# np.float64(0.6941490992339152)

# %%
s = pd.Series([1, 2, 3, 4])

result = s + 5
s
result
# Out:
# 0    6
# 1    7
# 2    8
# 3    9
# dtype: int64

# %%
df
# Out:
#                    A         B         C         D
# 2013-01-01  0.694149  0.277558 -1.622971  1.016996
# 2013-01-02 -0.729708 -1.136329  0.509865  1.844282
# 2013-01-03  1.105291  0.828767  0.098230 -1.716570
# 2013-01-04  1.741801 -0.931883  1.492771  0.397975
# 2013-01-05  0.176095 -2.725450  2.009585  0.474134
# 2013-01-06  0.448951  0.063204  0.242521 -0.273548

# %%
df.iloc[2:5, 0:2]
# Out:
#                    A         B
# 2013-01-03  1.105291  0.828767
# 2013-01-04  1.741801 -0.931883
# 2013-01-05  0.176095 -2.725450

# %%
df.iloc[1:3, :]
# Out:
#                    A         B         C         D
# 2013-01-02 -0.729708 -1.136329  0.509865  1.844282
# 2013-01-03  1.105291  0.828767  0.098230 -1.716570

# %%
df.iloc[:, 1:3]
# Out:
#                    B         C
# 2013-01-01  0.277558 -1.622971
# 2013-01-02 -1.136329  0.509865
# 2013-01-03  0.828767  0.098230
# 2013-01-04 -0.931883  1.492771
# 2013-01-05 -2.725450  2.009585
# 2013-01-06  0.063204  0.242521

# %%
df.iloc[1,2]
# Out:
# np.float64(0.5098652940099118)

# %%
df.iat[1,2]
# Out:
# np.float64(0.5098652940099118)

# %% [markdown]
# iat is used for a single position. more performant

# %% [markdown]
# Boolean indexing
# Select rows where df.A is greater than 1

# %%
df[df["A"] > 1]
# Out:
#                    A         B         C         D
# 2013-01-03  1.105291  0.828767  0.098230 -1.716570
# 2013-01-04  1.741801 -0.931883  1.492771  0.397975

# %%
df[df > 1]
# Out:
#                    A   B         C         D
# 2013-01-01       NaN NaN       NaN  1.016996
# 2013-01-02       NaN NaN       NaN  1.844282
# 2013-01-03  1.105291 NaN       NaN       NaN
# 2013-01-04  1.741801 NaN  1.492771       NaN
# 2013-01-05       NaN NaN  2.009585       NaN
# 2013-01-06       NaN NaN       NaN       NaN

# %%
df2 = df.copy()
df2["E"] = ["one", "two", "three", "four", "three", "five"]
df2
# Out:
#                    A         B         C         D      E
# 2013-01-01  0.694149  0.277558 -1.622971  1.016996    one
# 2013-01-02 -0.729708 -1.136329  0.509865  1.844282    two
# 2013-01-03  1.105291  0.828767  0.098230 -1.716570  three
# 2013-01-04  1.741801 -0.931883  1.492771  0.397975   four
# 2013-01-05  0.176095 -2.725450  2.009585  0.474134  three
# 2013-01-06  0.448951  0.063204  0.242521 -0.273548   five

# %%
df2[df2["E"].isin(["two", "four"])]
# Out:
#                    A         B         C         D     E
# 2013-01-02 -0.729708 -1.136329  0.509865  1.844282   two
# 2013-01-04  1.741801 -0.931883  1.492771  0.397975  four

# %% [markdown]
# Setting
# setting a new column automatically aligns the data by indexes

# %%
s1 = pd.Series([1, 2, 3, 4, 5, 6], index=pd.date_range("20130102", periods=6))
s1
df["F"] = s1
df
# Out:
#                    A         B         C         D    F
# 2013-01-01  0.694149  0.277558 -1.622971  1.016996  NaN
# 2013-01-02 -0.729708 -1.136329  0.509865  1.844282  1.0
# 2013-01-03  1.105291  0.828767  0.098230 -1.716570  2.0
# 2013-01-04  1.741801 -0.931883  1.492771  0.397975  3.0
# 2013-01-05  0.176095 -2.725450  2.009585  0.474134  4.0
# 2013-01-06  0.448951  0.063204  0.242521 -0.273548  5.0

# %%
df.at[dates[0], "A"] = 0
df
# Out:
#                    A         B         C         D    F
# 2013-01-01  0.000000  0.277558 -1.622971  1.016996  NaN
# 2013-01-02 -0.729708 -1.136329  0.509865  1.844282  1.0
# 2013-01-03  1.105291  0.828767  0.098230 -1.716570  2.0
# 2013-01-04  1.741801 -0.931883  1.492771  0.397975  3.0
# 2013-01-05  0.176095 -2.725450  2.009585  0.474134  4.0
# 2013-01-06  0.448951  0.063204  0.242521 -0.273548  5.0

# %%
df.loc[:, "D"] = np.array([5] * len(df))
df
# Out:
#                    A         B         C    D    F
# 2013-01-01  0.000000  0.277558 -1.622971  5.0  NaN
# 2013-01-02 -0.729708 -1.136329  0.509865  5.0  1.0
# 2013-01-03  1.105291  0.828767  0.098230  5.0  2.0
# 2013-01-04  1.741801 -0.931883  1.492771  5.0  3.0
# 2013-01-05  0.176095 -2.725450  2.009585  5.0  4.0
# 2013-01-06  0.448951  0.063204  0.242521  5.0  5.0

# %%
df2 = df.copy()
df2[df2 > 0] = -df2

df2
# Out:
#                    A         B         C    D    F
# 2013-01-01  0.000000 -0.277558 -1.622971 -5.0  NaN
# 2013-01-02 -0.729708 -1.136329 -0.509865 -5.0 -1.0
# 2013-01-03 -1.105291 -0.828767 -0.098230 -5.0 -2.0
# 2013-01-04 -1.741801 -0.931883 -1.492771 -5.0 -3.0
# 2013-01-05 -0.176095 -2.725450 -2.009585 -5.0 -4.0
# 2013-01-06 -0.448951 -0.063204 -0.242521 -5.0 -5.0

# %%
df2
# Out:
#                    A         B         C    D    F
# 2013-01-01  0.000000 -0.277558 -1.622971 -5.0  NaN
# 2013-01-02 -0.729708 -1.136329 -0.509865 -5.0 -1.0
# 2013-01-03 -1.105291 -0.828767 -0.098230 -5.0 -2.0
# 2013-01-04 -1.741801 -0.931883 -1.492771 -5.0 -3.0
# 2013-01-05 -0.176095 -2.725450 -2.009585 -5.0 -4.0
# 2013-01-06 -0.448951 -0.063204 -0.242521 -5.0 -5.0

# %% [markdown]
# Missing data
# for numpy data types np.nan represents missing data. It is default not included in computations

# %%
df1 = df.reindex(index=dates[0:4], columns=list(df.columns) + ["E"])
df1

df1.loc[dates[0]: dates[1], "E"] = 1
df1
df1.drop(columns=["E"])
df1.loc[dates[0]: dates[1], "E"] = 1
df1
# Out:
#                    A         B         C    D    F    E    E
# 2013-01-01  0.000000  0.277558 -1.622971  5.0  NaN  1.0  1.0
# 2013-01-02 -0.729708 -1.136329  0.509865  5.0  1.0  1.0  1.0
# 2013-01-03  1.105291  0.828767  0.098230  5.0  2.0  NaN  NaN
# 2013-01-04  1.741801 -0.931883  1.492771  5.0  3.0  NaN  NaN

# %%
df1.dropna(how="any")
# Out:
#                    A         B         C    D    F    E    E
# 2013-01-02 -0.729708 -1.136329  0.509865  5.0  1.0  1.0  1.0

# %%
df1.fillna(value=3)
# Out:
#                    A         B         C    D    F    E    E
# 2013-01-01  0.000000  0.277558 -1.622971  5.0  3.0  1.0  1.0
# 2013-01-02 -0.729708 -1.136329  0.509865  5.0  1.0  1.0  1.0
# 2013-01-03  1.105291  0.828767  0.098230  5.0  2.0  3.0  3.0
# 2013-01-04  1.741801 -0.931883  1.492771  5.0  3.0  3.0  3.0

# %%
df
# Out:
#                    A         B         C    D    F    E
# 2013-01-01  0.000000  0.277558 -1.622971  5.0  NaN  1.0
# 2013-01-02 -0.729708 -1.136329  0.509865  5.0  1.0  1.0
# 2013-01-03  1.105291  0.828767  0.098230  5.0  2.0  NaN
# 2013-01-04  1.741801 -0.931883  1.492771  5.0  3.0  NaN
# 2013-01-05  0.176095 -2.725450  2.009585  5.0  4.0  NaN
# 2013-01-06  0.448951  0.063204  0.242521  5.0  5.0  NaN

# %%
df.mean()
# Out:
# A    0.457072
# B   -0.604022
# C    0.455000
# D    5.000000
# F    3.000000
# E    1.000000
# dtype: float64

# %%
df.mean(axis=1)
# Out:
# 2013-01-01    0.930917
# 2013-01-02    0.940638
# 2013-01-03    1.806458
# 2013-01-04    2.060538
# 2013-01-05    1.692046
# 2013-01-06    2.150935
# Freq: D, dtype: float64

# %%
df
# Out:
#                    A         B         C    D    F    E
# 2013-01-01  0.000000  0.277558 -1.622971  5.0  NaN  1.0
# 2013-01-02 -0.729708 -1.136329  0.509865  5.0  1.0  1.0
# 2013-01-03  1.105291  0.828767  0.098230  5.0  2.0  NaN
# 2013-01-04  1.741801 -0.931883  1.492771  5.0  3.0  NaN
# 2013-01-05  0.176095 -2.725450  2.009585  5.0  4.0  NaN
# 2013-01-06  0.448951  0.063204  0.242521  5.0  5.0  NaN

# %%
df.dropna()
row_means = df.sum(axis=1) / df.shape[1]
row_means
# Out:
# 2013-01-01    0.775764
# 2013-01-02    0.940638
# 2013-01-03    1.505381
# 2013-01-04    1.717115
# 2013-01-05    1.410038
# 2013-01-06    1.792446
# Freq: D, dtype: float64

# %%
row_means = df.sum(axis=0) / df.count(axis=0)
row_means
df
# Out:
#                    A         B         C    D    F    E
# 2013-01-01  0.000000  0.277558 -1.622971  5.0  NaN  1.0
# 2013-01-02 -0.729708 -1.136329  0.509865  5.0  1.0  1.0
# 2013-01-03  1.105291  0.828767  0.098230  5.0  2.0  NaN
# 2013-01-04  1.741801 -0.931883  1.492771  5.0  3.0  NaN
# 2013-01-05  0.176095 -2.725450  2.009585  5.0  4.0  NaN
# 2013-01-06  0.448951  0.063204  0.242521  5.0  5.0  NaN

# %% [markdown]
# Why am I getting different sums. Auto ignoring nan

# %%
s = pd.Series([1, 3, 5, np.nan, 6, 8], index=dates)
s
# Out:
# 2013-01-01    1.0
# 2013-01-02    3.0
# 2013-01-03    5.0
# 2013-01-04    NaN
# 2013-01-05    6.0
# 2013-01-06    8.0
# Freq: D, dtype: float64

# %%
df
# Out:
#                    A         B         C    D    F    E
# 2013-01-01  0.000000  0.277558 -1.622971  5.0  NaN  1.0
# 2013-01-02 -0.729708 -1.136329  0.509865  5.0  1.0  1.0
# 2013-01-03  1.105291  0.828767  0.098230  5.0  2.0  NaN
# 2013-01-04  1.741801 -0.931883  1.492771  5.0  3.0  NaN
# 2013-01-05  0.176095 -2.725450  2.009585  5.0  4.0  NaN
# 2013-01-06  0.448951  0.063204  0.242521  5.0  5.0  NaN

# %%
# df.agg(lambda x: np.mean(x) * 5.6)

df.transform(lambda x: x + 1)
# Out:
#                    A         B         C    D    F    E
# 2013-01-01  1.000000  1.277558 -0.622971  6.0  NaN  2.0
# 2013-01-02  0.270292 -0.136329  1.509865  6.0  2.0  2.0
# 2013-01-03  2.105291  1.828767  1.098230  6.0  3.0  NaN
# 2013-01-04  2.741801  0.068117  2.492771  6.0  4.0  NaN
# 2013-01-05  1.176095 -1.725450  3.009585  6.0  5.0  NaN
# 2013-01-06  1.448951  1.063204  1.242521  6.0  6.0  NaN

# %%
s = pd.Series(np.random.randint(0, 7, size=10))
s

s.value_counts()
# Out:
# 2    3
# 0    3
# 5    2
# 3    1
# 6    1
# Name: count, dtype: int64

# %%
s = pd.Series(["A", "B", "C", "Aaba", "Baca", np.nan, "CABA", "dog", "cat"])

s.str.lower()
# Out:
# 0       a
# 1       b
# 2       c
# 3    aaba
# 4    baca
# 5     NaN
# 6    caba
# 7     dog
# 8     cat
# dtype: object

# %%
df = pd.DataFrame(np.random.randn(10, 4))
df

pieces = [df[:3], df[3:7], df[7:]]
pieces
# Out:
# [          0         1         2         3
#  0  0.774475 -1.687874 -0.131361  0.599282
#  1 -0.999813  0.342642  1.181544  1.436507
#  2  0.675606  0.113339  0.232433  1.243348,
#            0         1         2         3
#  3  1.132472  0.175171 -0.739922  0.212323
#  4  0.339154 -0.620799  0.793427 -0.675824
#  5  0.886662 -1.604024  0.673930  0.020020
#  6  0.696560 -0.819954  0.407971 -1.872166,
#            0         1         2         3
#  7 -0.812712  0.277936  0.594093 -0.436730
#  8 -0.335898 -0.900710 -0.173937 -1.767385
#  9  0.869091 -0.652255 -0.281934 -0.434788]

# %%
pd.concat(pieces)
# Out:
#           0         1         2         3
# 0  0.774475 -1.687874 -0.131361  0.599282
# 1 -0.999813  0.342642  1.181544  1.436507
# 2  0.675606  0.113339  0.232433  1.243348
# 3  1.132472  0.175171 -0.739922  0.212323
# 4  0.339154 -0.620799  0.793427 -0.675824
# 5  0.886662 -1.604024  0.673930  0.020020
# 6  0.696560 -0.819954  0.407971 -1.872166
# 7 -0.812712  0.277936  0.594093 -0.436730
# 8 -0.335898 -0.900710 -0.173937 -1.767385
# 9  0.869091 -0.652255 -0.281934 -0.434788

# %%
left = pd.DataFrame({"key": ["foo", "foo"], "lval": [1, 2]})
left
# Out:
#    key  lval
# 0  foo     1
# 1  foo     2

# %%
right = pd.DataFrame({"key": ["foo", "foo"], "rval": [4, 5]}) 
right
# Out:
#    key  rval
# 0  foo     4
# 1  foo     5

# %%
pd.merge(left, right, on="key")
# Out:
#    key  lval  rval
# 0  foo     1     4
# 1  foo     1     5
# 2  foo     2     4
# 3  foo     2     5
